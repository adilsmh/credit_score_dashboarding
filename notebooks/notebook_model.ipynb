# %% [markdown]
# # Libraries

# %%
import os
import sys
from statistics import mean
import glob
import chardet
from IPython.core import display as ICD
from tqdm.notebook import tqdm

# visualisation
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['savefig.facecolor'] = "0.8"
plt.rcParams.update({'figure.figsize': (15, 5), 'figure.dpi': 120})
plt.style.use('fivethirtyeight')

# preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from imblearn.over_sampling import SMOTE
from sklearn.compose import make_column_transformer
from sklearn.metrics import classification_report

# from pytorch_tabular.utils import get_balanced_sampler, get_class_weighted_cross_entropy

# models
# from lazypredict.Supervised import LazyClassifier
# import tensorflow as tf
# from tensorflow import keras
# from pytorch_tabular import TabularModel
# from pytorch_tabular.models import CategoryEmbeddingModelConfig
# from pytorch_tabular.config import DataConfig, OptimizerConfig, TrainerConfig, ExperimentConfig

# from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from xgboost import XGBClassifier

# pipeline
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as imbpipeline

# performance
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, roc_auc_score, plot_roc_curve, roc_curve
from scikitplot.estimators import plot_learning_curve
from sklearn.model_selection import learning_curve

# autoML
# from autosklearn.classification import AutoSklearnClassifier

# explainability
# from shap import summary_plot, TreeExplainer

# fine-tuning
from sklearn.model_selection import GridSearchCV

# model zxport
import joblib

# ignore warnings
# from sklearn.utils.testing import ignore_warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data fetching

# %%
def data_fetch_parse(path: str, all_files=False):
    # Get CSV files list from a folder
    csv_files = glob.glob(path + "/*.csv")
    csv_files_name = [file for file in os.listdir(
        path) if file.endswith(".csv")]

    # Read each CSV file into DataFrame
    # This creates a list of dataframes
    df_list = {}
    for file, file_name in zip(csv_files, csv_files_name):
        # Look at the first ten thousand bytes to guess the character encoding with confidence interval
        with open(file, 'rb') as rawdata:
            encod_type = chardet.detect(rawdata.read(10000))["encoding"]
            # parse data with given file path
            df = pd.read_csv(file, sep=None, delim_whitespace=None,
                             encoding=encod_type, engine="python")
            if set(["SK_ID_CURR"]).issubset(df.columns):
                df = df.drop("SK_ID_CURR", axis=1)
                df_list[file_name] = df
            else:
                df_list[file_name] = df
                
    # # define train, test parsed named csv files
    TRAIN, TEST = df_list["application_train.csv"], df_list["application_test.csv"]

    return TRAIN, TEST
    # return df_list

# %%
local_path = "../data/csv/train_test"
TRAIN, TEST = data_fetch_parse(local_path)

# %% [markdown]
# # Model building

# %% [markdown]
# ## Preprocessing

# %%
def preprocessing(data: pd.DataFrame, n_corr_fts: int):
    """
    Function for data preprocessing

    Parameters
    ----------
    data: pd.DataFrame
        Pandas dataframe containing data variables

    Returns
    -------
    X_train: np.array
    y_train: np.array
    X_test: np.array
    y_test: np.array
    """
    df = data.copy()  # define dataset copy 

    corr_fts = data.corr()[["TARGET"]].sort_values("TARGET", ascending=False).head(n_corr_fts).index  # retrieve nine most target correlated features
    df = df[corr_fts]

    df = df.drop_duplicates()  # drop duplicates
    df = df.dropna()  # drop null values
    # df.drop(["FLAG_DOCUMENT_3", "REG_CITY_NOT_LIVE_CITY", "REG_CITY_NOT_LIVE_CITY"], axis=1, inplace=True)  # drop co-correlated features 

    """Select features with "days" named headers to convert them into years"""
    for col in df.columns:
        if "days" in col.lower():
            df[col] = df[col].abs()
            df[col] = df[col].div(365)
            df[col] = df[col].round(decimals=0)
            df[col] = pd.to_numeric(df[col], downcast="integer")

    X = df.drop("TARGET", axis=1)
    y = df["TARGET"]

    cat_col_names = list(["REGION_RATING_CLIENT", "REG_CITY_NOT_WORK_CITY", "FLAG_EMP_PHONE"])  # define categorical features name list
    num_col_names = list(X.drop(cat_col_names, axis=1).columns)  # define discrete numerical features name list

    X = StandardScaler().fit_transform(X[num_col_names])  # standard scale numerical features 

    X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True)  # train / test split
    X_train, y_train = SMOTE().fit_resample(X_train, y_train)  # Over-sampling on minority class because of unbalancing 

    return X_train, y_train, X_test, y_test

# %%
X_train, y_train, X_test, y_test = preprocessing(TRAIN, n_corr_fts=10)

# %% [markdown]
# ## ML Models | Sklearn

# %%
def classification_models(models_list: list, X_train, y_train, X_test, y_test, only_models=False):
    """
    Function to instantiate a model or a series of models in a given list, 

    Parameters
    ----------
    models_list: list
        List containing a model or series of models to instantiate
    X_train
    y_train
    X_test
    y_test

    Returns
    Plot with models metrics, and a dictionary containing trained models.
    """
    classifiers = models_list
    # names = ["RBF SVM", "Random Forest", "Extremely Randomized Trees", "XGBoost"]
    names = [clf.__class__.__name__ for clf in models_list]

    monit_ls = []
    models_trained = {}

    for name, clf in zip(names, classifiers):
        model = clf.fit(X_train, y_train)
        models_trained[name] = model
        y_predict = model.predict(X_test)
        accuracy = accuracy_score(y_test, y_predict)
        recall = recall_score(y_test, y_predict)
        monit_ls.append([name, accuracy, recall])

    if not only_models:
        monit_df = pd.DataFrame(monit_ls, columns=["Model", "Accuracy", "Recall"])
        monit_df.style.background_gradient(cmap='Greens')

        ICD.display(monit_df)

    else:
        return models_trained

# %%
models = [RandomForestClassifier(), XGBClassifier(), ExtraTreesClassifier(), LogisticRegression()]

classification_models(models_list=models, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
# Out:
#                     Model  Accuracy    Recall
# 0  RandomForestClassifier  0.931202  0.001943
# 1           XGBClassifier  0.932937  0.001295
# 2    ExtraTreesClassifier  0.924478  0.009715
# 3      LogisticRegression  0.591854  0.579016

# %%
models_trained_dict = classification_models(models_list=models, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, only_models=True)

# %%
class performance_plots():

    # Learning curves
    def learning_curves(model, features, target):
        train_sizes, train_scores, test_scores = learning_curve(estimator=model,
                                                                X=features,
                                                                y=target,
                                                                cv=None,
                                                                scoring='recall',
                                                                shuffle=True)

        # Take the mean of cross-validated train scores and validation scores
        train_scores_mean = np.mean(train_scores, axis=1)
        test_scores_mean = np.mean(test_scores, axis=1)

        # Plot the learning curves!
        plt.plot(train_sizes, train_scores_mean, label='Training score')
        plt.plot(train_sizes, test_scores_mean, label='Test score')
        plt.ylabel('Recall', fontsize=14)
        plt.xlabel('Training set size', fontsize=14)
        plt.title('Learning curves', fontsize=18, y=1.03)
        plt.legend()
        
        plt.savefig("../reports/model/logistic_learning_curve.png")
        plt.show()

    # ROC_AUC curves
    def roc_auc(model, X_tst, y_tst):
        plot_roc_curve(model, X_tst, y_tst)
        plt.title('ROC Curve')
        plt.plot([0, 1], [0, 1], 'r--')
        
        plt.savefig("../reports/model/logistic_roc_auc.png")
        plt.show()

    # Confusion matrix
    def plot_confusion_matrix(y_tst, y_hat):
        rec = round(recall_score(y_tst, y_hat), 2)
        cm = confusion_matrix(y_tst, y_hat)
        sns.heatmap(cm, annot=True, fmt=".0f")
        plt.xlabel('y_pred')
        plt.ylabel('y')
        plt.title('Recall Score: {0}'.format(rec), size=20)

        plt.savefig("../reports/model/logistic_confusion_matrix.png")
        plt.show()

# %%
param_grid = {"penalty": ["l1", "l2", "elasticnet", "none"], "dual": [False, True], "fit_intercept": [False, True], "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"], "warm_start": [False, True]}

# %%
clf = GridSearchCV(models_trained_dict["LogisticRegression"], param_grid, scoring="recall", verbose=4, n_jobs=-1, refit=True, return_train_score=True)
clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 160 candidates, totalling 800 fits
# GridSearchCV(estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'dual': [False, True], 'fit_intercept': [False, True],
#                          'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                     'saga'],
#                          'warm_start': [False, True]},
#              return_train_score=True, scoring='recall', verbose=4)

# %%
# setting pipeline
corr_fts = TRAIN.corr()[["TARGET"]].sort_values(
    "TARGET", ascending=False).head(10).index

TRAIN_SET = TRAIN[corr_fts].drop(
    ["FLAG_DOCUMENT_3", "REG_CITY_NOT_LIVE_CITY", "REG_CITY_NOT_LIVE_CITY"], axis=1)
TRAIN_SET.dropna(inplace=True)

X = TRAIN_SET.drop("TARGET", axis=1)
y = TRAIN_SET["TARGET"]

categorical_features = list(
    ["REGION_RATING_CLIENT", "REG_CITY_NOT_WORK_CITY", "FLAG_EMP_PHONE"])
numerical_features = list(X.drop(cat_col_names, axis=1).columns)

numeric_transformer = Pipeline(
    steps=[("standard_scaler", StandardScaler())]
)

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numerical_features),
    ],
    remainder="passthrough"
)

# Append classifier to preprocessing pipeline.
# Now we have a full prediction pipeline.
# clf_pipe = imbpipeline(
#     steps=[("preprocessor", preprocessor), ("SMOTE", SMOTE()), ("classifier", GridSearchCV(LogisticRegression(), param_grid= {"penalty": ["l1", "l2", "elasticnet", "none"], "dual": [False, True], "fit_intercept": [False, True], "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"], "warm_start": [False, True]}, scoring="recall", n_jobs=-1, refit=True))]
# )
clf_pipe = imbpipeline(
    steps=[("preprocessor", preprocessor), ("SMOTE", SMOTE()), ("classifier", LogisticRegression(C=1.0,
                                                                                                 class_weight=None,
                                                                                                 dual=False,
                                                                                                 fit_intercept=False,
                                                                                                 intercept_scaling=1,
                                                                                                 l1_ratio=None,
                                                                                                 max_iter=100,
                                                                                                 multi_class="auto",
                                                                                                 n_jobs=None,
                                                                                                 penalty="l1",
                                                                                                 random_state=None,
                                                                                                 solver="liblinear",
                                                                                                 tol=0.0001,
                                                                                                 verbose=0,
                                                                                                 warm_start=False))]
)

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True)

clf_pipe.fit(X_train, y_train)
y_pred = clf_pipe.predict(X_test)
print(classification_report(y_test, y_pred))

# %%
model_clf = joblib.dump(value=clf, filename="../models/logistic_model.pkl")

# %% [markdown]
# ## Auto-sklearn

# %%
corr_fts = TRAIN.corr()[["TARGET"]].sort_values("TARGET", ascending=False).head(10).index

# %%
TRAIN_SET = TRAIN[corr_fts].dropna()

X = TRAIN_SET.drop("TARGET", axis=1)
y = TRAIN_SET["TARGET"]

# cat_col_names = list(["REGION_RATING_CLIENT_W_CITY", "REGION_RATING_CLIENT", "FLAG_DOCUMENT_3", "REG_CITY_NOT_WORK_CITY", "FLAG_EMP_PHONE", "REG_CITY_NOT_LIVE_CITY"])
cat_col_names = list(["REGION_RATING_CLIENT_W_CITY", "REGION_RATING_CLIENT", "REG_CITY_NOT_WORK_CITY", "FLAG_EMP_PHONE", "REG_CITY_NOT_LIVE_CITY"])
num_col_names = list(X.drop(cat_col_names, axis=1).columns)

X = StandardScaler().fit_transform(X[num_col_names])
# y = StandardScaler().fit(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True)
X_train, y_train = SMOTE().fit_resample(X_train, y_train)

# %%
classifier = AutoSklearnClassifier(
    time_left_for_this_task=300,
    memory_limit=None,
    include = {"feature_preprocessor": ["no_preprocessing"]
    },
    n_jobs=-1)

# %%
classifier.fit(X_train, y_train)
# Out:
# [WARNING] [2022-05-11 13:10:25,487:Client-AutoML(1):b7be37c2-d12b-11ec-806d-0242ac110002] Capping the per_run_time_limit to 149.0 to have time for a least 2 models in each process.
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 43 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 338 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 322 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 283 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 624 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 576 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 191 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 227 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 605 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 67 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 518 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 347 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 454 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 532 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 590 not found
# [WARNING] [2022-05-11 13:10:26,370:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 108 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 138 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 426 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 188 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 506 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 367 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 358 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 345 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 222 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 149 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 329 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 560 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 211 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 460 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 585 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 473 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 257 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 184 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 230 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 543 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 663 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 674 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 61 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 71 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 332 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 81 not found
# [WARNING] [2022-05-11 13:10:26,371:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 524 not found
# [WARNING] [2022-05-11 13:10:26,372:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 553 not found
# [WARNING] [2022-05-11 13:10:26,372:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 238 not found
# [WARNING] [2022-05-11 13:10:26,372:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 386 not found
# [WARNING] [2022-05-11 13:10:26,372:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 206 not found
# [WARNING] [2022-05-11 13:10:26,372:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 440 not found
# [WARNING] [2022-05-11 13:10:26,372:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 9 not found
# [WARNING] [2022-05-11 13:10:26,372:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 262 not found
# [WARNING] [2022-05-11 13:10:26,373:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 22 not found
# [WARNING] [2022-05-11 13:10:26,373:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 509 not found
# [WARNING] [2022-05-11 13:10:26,373:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 492 not found
# [WARNING] [2022-05-11 13:10:26,373:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 393 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 521 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 162 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 14 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 657 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 702 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 91 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 145 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 32 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 147 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 266 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 407 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 476 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 690 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 176 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 282 not found
# [WARNING] [2022-05-11 13:10:26,374:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 546 not found
# [WARNING] [2022-05-11 13:10:26,375:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 315 not found
# [WARNING] [2022-05-11 13:10:26,375:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 694 not found
# [WARNING] [2022-05-11 13:10:26,375:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 7 not found
# [WARNING] [2022-05-11 13:10:26,375:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 19 not found
# [WARNING] [2022-05-11 13:10:26,375:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 631 not found
# [WARNING] [2022-05-11 13:10:26,375:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 601 not found
# [WARNING] [2022-05-11 13:10:26,375:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 277 not found
# [WARNING] [2022-05-11 13:10:26,375:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 173 not found
# [WARNING] [2022-05-11 13:10:26,375:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 414 not found
# [WARNING] [2022-05-11 13:10:26,375:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 88 not found
# [WARNING] [2022-05-11 13:10:26,375:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 131 not found
# [WARNING] [2022-05-11 13:10:26,375:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 220 not found
# [WARNING] [2022-05-11 13:10:26,375:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 574 not found
# [WARNING] [2022-05-11 13:10:26,376:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 114 not found
# [WARNING] [2022-05-11 13:10:26,376:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 369 not found
# [WARNING] [2022-05-11 13:10:26,376:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 595 not found
# [WARNING] [2022-05-11 13:10:26,376:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 647 not found
# [WARNING] [2022-05-11 13:10:26,376:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 434 not found
# [WARNING] [2022-05-11 13:10:26,376:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 288 not found
# [WARNING] [2022-05-11 13:10:26,376:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 579 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 232 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 422 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 676 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 615 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 193 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 160 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 129 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 197 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 587 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 310 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 653 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 701 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 437 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 142 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 69 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 99 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 536 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 444 not found
# [WARNING] [2022-05-11 13:10:26,377:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 48 not found
# [WARNING] [2022-05-11 13:10:26,378:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 254 not found
# [WARNING] [2022-05-11 13:10:26,378:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 687 not found
# [WARNING] [2022-05-11 13:10:26,378:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 28 not found
# [WARNING] [2022-05-11 13:10:26,378:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 378 not found
# [WARNING] [2022-05-11 13:10:26,378:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 124 not found
# [WARNING] [2022-05-11 13:10:26,378:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 707 not found
# [WARNING] [2022-05-11 13:10:26,378:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 40 not found
# [WARNING] [2022-05-11 13:10:26,378:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 53 not found
# [WARNING] [2022-05-11 13:10:26,378:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 680 not found
# [WARNING] [2022-05-11 13:10:26,378:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 648 not found
# [WARNING] [2022-05-11 13:10:26,378:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 470 not found
# [WARNING] [2022-05-11 13:10:26,378:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 237 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 485 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 264 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 352 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 17 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 555 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 56 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 214 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 430 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 382 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 83 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 571 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 357 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 388 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 97 not found
# [WARNING] [2022-05-11 13:10:26,379:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 512 not found
# [WARNING] [2022-05-11 13:10:26,380:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 293 not found
# [WARNING] [2022-05-11 13:10:26,380:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 154 not found
# [WARNING] [2022-05-11 13:10:26,380:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 613 not found
# [WARNING] [2022-05-11 13:10:26,380:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 172 not found
# [WARNING] [2022-05-11 13:10:26,380:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 515 not found
# [WARNING] [2022-05-11 13:10:26,380:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 112 not found
# [WARNING] [2022-05-11 13:10:26,380:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 635 not found
# [WARNING] [2022-05-11 13:10:26,380:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 302 not found
# [WARNING] [2022-05-11 13:10:26,380:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 494 not found
# [WARNING] [2022-05-11 13:10:26,380:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 448 not found
# [WARNING] [2022-05-11 13:10:26,380:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 419 not found
# [WARNING] [2022-05-11 13:10:26,380:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 270 not found
# [WARNING] [2022-05-11 13:10:26,380:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 171 not found
# [WARNING] [2022-05-11 13:10:26,381:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 403 not found
# [WARNING] [2022-05-11 13:10:26,381:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 528 not found
# [WARNING] [2022-05-11 13:10:26,381:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 25 not found
# [WARNING] [2022-05-11 13:10:26,381:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 643 not found
# [WARNING] [2022-05-11 13:10:26,381:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 165 not found
# [WARNING] [2022-05-11 13:10:26,381:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 313 not found
# [WARNING] [2022-05-11 13:10:26,381:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 375 not found
# [WARNING] [2022-05-11 13:10:26,381:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 243 not found
# [WARNING] [2022-05-11 13:10:26,381:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 486 not found
# [WARNING] [2022-05-11 13:10:26,382:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 461 not found
# [WARNING] [2022-05-11 13:10:26,382:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 86 not found
# [WARNING] [2022-05-11 13:10:26,382:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 480 not found
# [WARNING] [2022-05-11 13:10:26,382:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 622 not found
# [WARNING] [2022-05-11 13:10:26,382:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 640 not found
# [WARNING] [2022-05-11 13:10:26,382:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 363 not found
# [WARNING] [2022-05-11 13:10:26,382:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 499 not found
# [WARNING] [2022-05-11 13:10:26,382:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 548 not found
# [WARNING] [2022-05-11 13:10:26,382:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 538 not found
# [WARNING] [2022-05-11 13:10:26,382:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 58 not found
# [WARNING] [2022-05-11 13:10:26,382:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 317 not found
# [WARNING] [2022-05-11 13:10:26,382:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 291 not found
# [WARNING] [2022-05-11 13:10:26,382:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 304 not found
# [WARNING] [2022-05-11 13:10:26,383:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 120 not found
# [WARNING] [2022-05-11 13:10:26,383:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 452 not found
# [WARNING] [2022-05-11 13:10:26,383:Client-AutoMLSMBO(1)::b7be37c2-d12b-11ec-806d-0242ac110002] Configuration 275 not found
# AutoSklearnClassifier(include={'feature_preprocessor': ['no_preprocessing']},
#                       memory_limit=None, n_jobs=-1, per_run_time_limit=240,
#                       time_left_for_this_task=300)

# %%
print(classifier.leaderboard())
# Out:
#           rank  ensemble_weight               type      cost    duration
# model_id
# 14           1             0.44  gradient_boosting  0.214664  125.690800
# 15           2             0.02  gradient_boosting  0.289001   55.379998
# 20           3             0.54                qda  0.436373    2.840280

# %%
predictions = classifier.predict(X_test)
print("Recall score:", recall_score(y_test, predictions))
# Out:
# Accuracy score: 0.3028225163450805

# %% [markdown]
# ## PyTorch tabular

# %%
corr_fts = TRAIN.corr()[["TARGET"]].sort_values("TARGET", ascending=False).head(10).index

# %%
cat_col_names = list(["REGION_RATING_CLIENT_W_CITY", "REGION_RATING_CLIENT", "REG_CITY_NOT_WORK_CITY", "FLAG_EMP_PHONE", "REG_CITY_NOT_LIVE_CITY", "FLAG_DOCUMENT_3"])
num_col_names = list(TRAIN[corr_fts].drop(cat_col_names, axis=1).drop("TARGET", axis=1).columns)

# %%
TRAIN_PYTORCH = TRAIN[corr_fts].dropna()
TRAIN_PYTORCH.isnull().sum()
# Out:
# TARGET                         0
# DAYS_BIRTH                     0
# REGION_RATING_CLIENT_W_CITY    0
# REGION_RATING_CLIENT           0
# DAYS_LAST_PHONE_CHANGE         0
# DAYS_ID_PUBLISH                0
# REG_CITY_NOT_WORK_CITY         0
# FLAG_EMP_PHONE                 0
# REG_CITY_NOT_LIVE_CITY         0
# FLAG_DOCUMENT_3                0
# dtype: int64

# %%
X_train, X_test = train_test_split(TRAIN_PYTORCH, test_size=.3, shuffle=True, stratify=y)
X_train = SMOTE().fit_resample(X_train, X_train["TARGET"])
# Out:
# (        TARGET  DAYS_BIRTH  REGION_RATING_CLIENT_W_CITY  REGION_RATING_CLIENT  \
#  0            0       -9300                            2                     2
#  1            0      -12663                            3                     3
#  2            0      -10043                            2                     2
#  3            0      -11283                            2                     2
#  4            0      -22933                            2                     2
#  ...        ...         ...                          ...                   ...
#  395755       1      -19051                            2                     2
#  395756       1       -9591                            2                     2
#  395757       1      -20055                            2                     2
#  395758       1      -10981                            2                     2
#  395759       1      -13721                            2                     2
#
#          DAYS_LAST_PHONE_CHANGE  DAYS_ID_PUBLISH  REG_CITY_NOT_WORK_CITY  \
#  0                  -686.000000            -1962                       1
#  1                  -560.000000            -4376                       1
#  2                  -254.000000             -699                       0
#  3                  -491.000000            -2502                       1
#  4                  -446.000000            -4560                       0
#  ...                        ...              ...                     ...
#  395755             -954.960086            -2590                       0
#  395756                0.000000             -411                       1
#  395757            -1771.600878            -3527                       0
#  395758              -11.154399            -2582                       0
#  395759             -286.135062            -2309                       0
#
#          FLAG_EMP_PHONE  REG_CITY_NOT_LIVE_CITY  FLAG_DOCUMENT_3
#  0                    1                       0                1
#  1                    1                       0                1
#  2                    1                       0                0
#  3                    1                       1                1
#  4                    0                       0                1
#  ...                ...                     ...              ...
#  395755               1                       0                1
#  395756               1                       1                1
#  395757               1                       0                0
#  395758               1                       0                0
#  395759               1                       0                1
#
#  [395760 rows x 10 columns],
#  0         0
#  1         0
#  2         0
#  3         0
#  4         0
#           ..
#  395755    1
#  395756    1
#  395757    1
#  395758    1
#  395759    1
#  Name: TARGET, Length: 395760, dtype: int64)

# %%
data_config = DataConfig(
    # target should always be a list. Multi-targets are only supported for regression. Multi-Task Classification is not implemented
    target=["TARGET"],
    continuous_cols=num_col_names,
    categorical_cols=cat_col_names,
)
trainer_config = TrainerConfig(
    auto_lr_find=True,  # runs the LRFinder to automatically derive a learning rate
    batch_size=1024,
    max_epochs=100,
    gpus=None,  # index of the GPU to use, -1 means all available GPUs, None, means CPU
)
optimizer_config = OptimizerConfig()

model_config = CategoryEmbeddingModelConfig(
    task="classification",
    layers="1024-512-512",  # number of nodes in each layer
    activation="LeakyReLU",  # activation between each layers
    learning_rate=1e-3,
    metrics=["recall", "f1"],
    metrics_params=[{"num_classes": 2}, {}]
)
tabular_model = TabularModel(
    data_config=data_config,
    model_config=model_config,
    optimizer_config=optimizer_config,
    trainer_config=trainer_config,
)

# %%
# weighted_loss = get_class_weighted_cross_entropy(X_train["TARGET"].values.ravel(), mu=0.1)  # class imbalance handling with smoothed class weights and weighted loss initialization 
# sampler = get_balanced_sampler(X_train["TARGET"].values.ravel())  # WeightedRandomSampler implementation using inverse frequency sampling to combat imbalance
tabular_model.fit(train=X_train)

# %%
result = tabular_model.predict(X_test.drop("TARGET", axis=1))
# Out:
# Generating Predictions...: 100%|██████████| 91/91 [00:02<00:00, 35.48it/s]

# %%
result
# Out:
#         DAYS_BIRTH  REGION_RATING_CLIENT_W_CITY  REGION_RATING_CLIENT  \
# 280794      -12053                            2                     2
# 263702      -10916                            2                     2
# 36464       -10066                            1                     1
# 241741      -15064                            1                     1
# 133587      -22026                            2                     2
# ...            ...                          ...                   ...
# 293086       -9975                            3                     3
# 46232       -11631                            1                     1
# 109168      -15733                            2                     2
# 210126      -20035                            2                     2
# 220417       -8961                            2                     2
#
#         DAYS_LAST_PHONE_CHANGE  DAYS_ID_PUBLISH  REG_CITY_NOT_WORK_CITY  \
# 280794                 -1939.0            -3569                       1
# 263702                    -3.0            -3534                       0
# 36464                  -1059.0            -2511                       1
# 241741                  -239.0            -4112                       0
# 133587                 -1237.0            -4646                       0
# ...                        ...              ...                     ...
# 293086                 -1653.0            -2327                       0
# 46232                  -2040.0            -3984                       1
# 109168                 -1741.0            -4150                       0
# 210126                 -2154.0            -3571                       0
# 220417                     0.0            -1598                       0
#
#         FLAG_EMP_PHONE  REG_CITY_NOT_LIVE_CITY  FLAG_DOCUMENT_3  \
# 280794               1                       0                1
# 263702               1                       0                1
# 36464                1                       1                0
# 241741               1                       0                1
# 133587               1                       0                1
# ...                ...                     ...              ...
# 293086               1                       0                1
# 46232                1                       0                1
# 109168               1                       0                1
# 210126               1                       0                0
# 220417               1                       0                1
#
#         0_probability  1_probability  prediction
# 280794       0.727038       0.272962           0
# 263702       0.703117       0.296883           0
# 36464        0.948764       0.051236           0
# 241741       0.849572       0.150428           0
# 133587       0.827132       0.172868           0
# ...               ...            ...         ...
# 293086       0.671546       0.328454           0
# 46232        0.905132       0.094868           0
# 109168       0.756485       0.243515           0
# 210126       0.811613       0.188388           0
# 220417       0.687774       0.312226           0
#
# [92253 rows x 12 columns]

# %%
conf_matrix = confusion_matrix(y_true=X_test["TARGET"], y_pred=result["prediction"])

# %%
conf_matrix
# Out:
# array([[84725,     0],
#        [ 7528,     0]], dtype=int64)

# %% [markdown]
# ## Tensorflow

# %% [markdown]
# Work in progress!!
